# %%
# First import the file

# %%
import pandas as pd
import numpy as np
marketing_data = pd.read_csv('marketing_customer_analysis.csv')

# %%
# Exercise 1 - show the dataframe shape

marketing_data.shape
marketing_data.head
# Out:
# <bound method NDFrame.head of        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0         Basic   College           2/18/11         Employed      M  ...
# 1         Basic   College           1/18/11       Unemployed      F  ...
# 2         Basic  Bachelor           2/10/11         Employed      M  ...
# 3      Extended   College           1/11/11         Employed      M  ...
# 4       Premium  Bachelor           1/17/11    Medical Leave      F  ...
# ...         ...       ...               ...              ...    ...  ...
# 10905   Premium  Bachelor           1/19/11       Unemployed      F  ...
# 10906     Basic   College            1/6/11         Employed      F  ...
# 10907  Extended  Bachelor            2/6/11         Employed      F  ...
# 10908   Premium   College           2/13/11         Employed      F  ...
# 10909     Basic  Bachelor            1/8/11       Unemployed      M  ...
#
#        Number of Open Complaints Number of Policies     Policy Type  \
# 0                            0.0                  9  Corporate Auto
# 1                            0.0                  1   Personal Auto
# 2                            0.0                  2   Personal Auto
# 3                            0.0                  2  Corporate Auto
# 4                            NaN                  7   Personal Auto
# ...                          ...                ...             ...
# 10905                        NaN                  7   Personal Auto
# 10906                        0.0                  6   Personal Auto
# 10907                        0.0                  2  Corporate Auto
# 10908                        4.0                  6   Personal Auto
# 10909                        0.0                  3   Personal Auto
#
#              Policy  Renew Offer Type  Sales Channel  Total Claim Amount  \
# 0      Corporate L3            Offer3          Agent          292.800000
# 1       Personal L3            Offer4    Call Center          744.924331
# 2       Personal L3            Offer3    Call Center          480.000000
# 3      Corporate L3            Offer2         Branch          484.013411
# 4       Personal L2            Offer1         Branch          707.925645
# ...             ...               ...            ...                 ...
# 10905   Personal L1            Offer3            Web         1214.400000
# 10906   Personal L3            Offer2         Branch          273.018929
# 10907  Corporate L3            Offer1            Web          381.306996
# 10908   Personal L1            Offer1         Branch          618.288849
# 10909   Personal L1            Offer4            Web         1021.719397
#
#        Vehicle Class Vehicle Size Vehicle Type
# 0      Four-Door Car      Medsize          NaN
# 1      Four-Door Car      Medsize          NaN
# 2                SUV      Medsize            A
# 3      Four-Door Car      Medsize            A
# 4      Four-Door Car      Medsize          NaN
# ...              ...          ...          ...
# 10905     Luxury Car      Medsize            A
# 10906  Four-Door Car      Medsize            A
# 10907     Luxury SUV      Medsize          NaN
# 10908            SUV      Medsize            A
# 10909            SUV      Medsize          NaN
#
# [10910 rows x 26 columns]>

# %%
# Exercise 2 - standardize header names

#First display the headers and check what needs to be done
display(marketing_data.columns)

#Put everything in lower cases
cols = []
for colname in marketing_data.columns:
    cols.append(colname.lower())
marketing_data.columns = cols

# check if it worked
display(marketing_data.columns)
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')
# Index(['unnamed: 0', 'customer', 'state', 'customer lifetime value',
#        'response', 'coverage', 'education', 'effective to date',
#        'employmentstatus', 'gender', 'income', 'location code',
#        'marital status', 'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'total claim amount', 'vehicle class', 'vehicle size',
#        'vehicle type'],
#       dtype='object')

# %%
# Exercise 3 - which columns are numerical

marketing_data.select_dtypes('number').columns
# Out:
# Index(['unnamed: 0', 'customer lifetime value', 'income',
#        'monthly premium auto', 'months since last claim',
#        'months since policy inception', 'number of open complaints',
#        'number of policies', 'total claim amount'],
#       dtype='object')

# %%
# Exercise 4 - which columns are categorical

marketing_data.select_dtypes('object').columns
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective to date', 'employmentstatus', 'gender', 'location code',
#        'marital status', 'policy type', 'policy', 'renew offer type',
#        'sales channel', 'vehicle class', 'vehicle size', 'vehicle type'],
#       dtype='object')

# %%
# Exercise 5 - check and deal with NaN values (no values) - decide what to do with them and comment

# use isna to show if there are na values - show in a sum
marketing_data.isna()
display(marketing_data.isna().sum())

# Check what percentage that is from the total values
round(marketing_data.isna().sum()/len(marketing_data),4)*100  # shows the percentage of null values in a column
nulls_df = pd.DataFrame(round(marketing_data.isna().sum()/len(marketing_data),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls'] #creates a table that looks nicer than the first code (round...)
nulls_df
# Out:
# unnamed: 0                          0
# customer                            0
# state                             631
# customer lifetime value             0
# response                          631
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           633
# months since policy inception       0
# number of open complaints         633
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                     622
# vehicle size                      622
# vehicle type                     5482
# dtype: int64
#                       header_name  percent_nulls
# 0                      unnamed: 0           0.00
# 1                        customer           0.00
# 2                           state           5.78
# 3         customer lifetime value           0.00
# 4                        response           5.78
# 5                        coverage           0.00
# 6                       education           0.00
# 7               effective to date           0.00
# 8                employmentstatus           0.00
# 9                          gender           0.00
# 10                         income           0.00
# 11                  location code           0.00
# 12                 marital status           0.00
# 13           monthly premium auto           0.00
# 14        months since last claim           5.80
# 15  months since policy inception           0.00
# 16      number of open complaints           5.80
# 17             number of policies           0.00
# 18                    policy type           0.00
# 19                         policy           0.00
# 20               renew offer type           0.00
# 21                  sales channel           0.00
# 22             total claim amount           0.00
# 23                  vehicle class           5.70
# 24                   vehicle size           5.70
# 25                   vehicle type          50.25

# %%
### HOW DO I START?

# 1. Look at the categorical values
# 2. Consider the numerical values
# 3. Consider the value 'vehicle type' that is missing most of the values

# %%
## CONSIDER CATEGORICAL VALUES 

# 1. Check the count for state values, and response values - the same rows miss the same two values
    #However between state and response there no obvious relationship
display(marketing_data['state'].unique())
display(marketing_data['state'].value_counts(dropna=False))

display(marketing_data['response'].unique())
display(marketing_data['response'].value_counts(dropna=False))

# 2. Check the count for vehicle class, and vehicle size values - the same rows miss the same two values
    #Between vehicle class and vehicle size there is an obvious relationship

display(marketing_data['vehicle class'].unique())
display(marketing_data['vehicle class'].value_counts(dropna=False))

display(marketing_data['vehicle size'].unique())
display(marketing_data['vehicle size'].value_counts(dropna=False))
# Out:
# array(['Arizona', 'California', 'Washington', 'Oregon', nan, 'Nevada'],
#       dtype=object)
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# NaN            631
# Name: state, dtype: int64
# array(['No', 'Yes', nan], dtype=object)
# No     8813
# Yes    1466
# NaN     631
# Name: response, dtype: int64
# array(['Four-Door Car', 'SUV', 'Two-Door Car', 'Sports Car', 'Luxury Car',
#        'Luxury SUV', nan], dtype=object)
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# NaN               622
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle class, dtype: int64
# array(['Medsize', 'Small', 'Large', nan], dtype=object)
# Medsize    7251
# Small      1966
# Large      1071
# NaN         622
# Name: vehicle size, dtype: int64

# %%
## CONSIDER CATEGORICAL VALUES 

# 3. FILL IN THE MISSING VALUE WITH THE MOST USED VALUE, where it makes sense - FOR RESPONSE, VEHICLE CLASS AND SIZE

marketing_data['response'] = marketing_data['response'].fillna('No')

marketing_data['vehicle class'] = marketing_data['vehicle class'].fillna('Four-Door Car')
marketing_data['vehicle size'] = marketing_data['vehicle size'].fillna('Medsize')

# 4. Check if this is now true

display(marketing_data['response'].value_counts())

display(marketing_data['vehicle class'].value_counts())
display(marketing_data['vehicle size'].value_counts())
# Out:
# No     9444
# Yes    1466
# Name: response, dtype: int64
# Four-Door Car    5834
# Two-Door Car     2118
# SUV              2012
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle class, dtype: int64
# Medsize    7873
# Small      1966
# Large      1071
# Name: vehicle size, dtype: int64

# %%
## CONSIDER CATEGORICAL VALUES 

# 5. Let's look at the rows that have nothing in state
marketing_data[marketing_data['state'].isna()==True].head(10)
# nothing obvious to spot - most effective to delete those rows

marketing_data = marketing_data[marketing_data['state'].isna()==False]
print(marketing_data.isna().sum())
# Out:
# unnamed: 0                          0
# customer                            0
# state                               0
# customer lifetime value             0
# response                            0
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           591
# months since policy inception       0
# number of open complaints         591
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                       0
# vehicle size                        0
# vehicle type                     5164
# dtype: int64

# %%
# Check how many values are na in the whole dataset

display(marketing_data.isna().sum())
# Out:
# unnamed: 0                          0
# customer                            0
# state                               0
# customer lifetime value             0
# response                            0
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim           591
# months since policy inception       0
# number of open complaints         591
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                       0
# vehicle size                        0
# vehicle type                     5164
# dtype: int64

# %%
## NOW CONSIDER THE NUMERICAL VALUES 'months since last claim', 'number of open complaints'

# They seem to have an obvious relationship as well
#Get the mean for the 'months since last claim' and 'number of open complaints' and fill in the missing values

import numpy as np

# 1. Calculate the mean of the column 'months since last claim'
mean_months_since_last_claim = marketing_data['months since last claim'].mean()
print(mean_months_since_last_claim)

mean_number_of_open_complaints = marketing_data['number of open complaints'].mean()
print(mean_number_of_open_complaints)

# 2. Fill in the missing values
marketing_data['months since last claim'] = marketing_data['months since last claim'].fillna(mean_months_since_last_claim)
display(marketing_data.shape)

marketing_data['number of open complaints'] = marketing_data['number of open complaints'].fillna(mean_number_of_open_complaints)
display(marketing_data.shape)

# 3. Check for na values
# Check how many values are na in the whole dataset

display(marketing_data.isna().sum())
# Out:
# 15.129851362510323
# 0.38356729975227083
# /var/folders/15/hgt62pt91txfslsjk64n8zd40000gp/T/ipykernel_2655/2973342827.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marketing_data['months since last claim'] = marketing_data['months since last claim'].fillna(mean_months_since_last_claim)
# (10279, 26)
# /var/folders/15/hgt62pt91txfslsjk64n8zd40000gp/T/ipykernel_2655/2973342827.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   marketing_data['number of open complaints'] = marketing_data['number of open complaints'].fillna(mean_number_of_open_complaints)
# (10279, 26)
# unnamed: 0                          0
# customer                            0
# state                               0
# customer lifetime value             0
# response                            0
# coverage                            0
# education                           0
# effective to date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location code                       0
# marital status                      0
# monthly premium auto                0
# months since last claim             0
# months since policy inception       0
# number of open complaints           0
# number of policies                  0
# policy type                         0
# policy                              0
# renew offer type                    0
# sales channel                       0
# total claim amount                  0
# vehicle class                       0
# vehicle size                        0
# vehicle type                     5164
# dtype: int64

# %%
## LOOK AT THE LAST VARIABLE VEHICLE TYPE

# Now let's look at vehicle type 50% of the values are missing. Just delete the column, filling in data would not help me in making a significant decision

marketing_data = marketing_data.drop(['vehicle type'], axis = 1)
display(marketing_data.shape)
# Out:
# (10279, 25)

# %%
## Control the dataframe for missing values

#5% of the original values are now deleted which is okay... maybe i could have created an unknown value for the states..

display(marketing_data.isna().sum())
display(marketing_data.shape)
# Out:
# unnamed: 0                       0
# customer                         0
# state                            0
# customer lifetime value          0
# response                         0
# coverage                         0
# education                        0
# effective to date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location code                    0
# marital status                   0
# monthly premium auto             0
# months since last claim          0
# months since policy inception    0
# number of open complaints        0
# number of policies               0
# policy type                      0
# policy                           0
# renew offer type                 0
# sales channel                    0
# total claim amount               0
# vehicle class                    0
# vehicle size                     0
# dtype: int64
# (10279, 25)

# %%
# Exercise 6 - create a new column with just the month

# 1. Check out the data type
display(marketing_data.dtypes) #We see that effective to date is an object, we need to convert into a date
display(marketing_data.head(2))

marketing_data['effective to date'] = pd.to_datetime(marketing_data['effective to date'], errors='coerce')
# check if the values look like a date now
display(marketing_data.head(2))
# Out:
# unnamed: 0                         int64
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# vehicle class                     object
# vehicle size                      object
# dtype: object
#    unnamed: 0 customer       state  customer lifetime value response coverage  \
# 0           0  DK49336     Arizona              4809.216960       No    Basic
# 1           1  KX64629  California              2228.525238       No    Basic
#
#   education effective to date employmentstatus gender  ...  \
# 0   College           2/18/11         Employed      M  ...
# 1   College           1/18/11       Unemployed      F  ...
#
#    months since policy inception number of open complaints number of policies  \
# 0                             52                       0.0                  9
# 1                             26                       0.0                  1
#
#       policy type        policy  renew offer type  sales channel  \
# 0  Corporate Auto  Corporate L3            Offer3          Agent
# 1   Personal Auto   Personal L3            Offer4    Call Center
#
#    total claim amount  vehicle class vehicle size
# 0          292.800000  Four-Door Car      Medsize
# 1          744.924331  Four-Door Car      Medsize
#
# [2 rows x 25 columns]
#    unnamed: 0 customer       state  customer lifetime value response coverage  \
# 0           0  DK49336     Arizona              4809.216960       No    Basic
# 1           1  KX64629  California              2228.525238       No    Basic
#
#   education effective to date employmentstatus gender  ...  \
# 0   College        2011-02-18         Employed      M  ...
# 1   College        2011-01-18       Unemployed      F  ...
#
#    months since policy inception number of open complaints number of policies  \
# 0                             52                       0.0                  9
# 1                             26                       0.0                  1
#
#       policy type        policy  renew offer type  sales channel  \
# 0  Corporate Auto  Corporate L3            Offer3          Agent
# 1   Personal Auto   Personal L3            Offer4    Call Center
#
#    total claim amount  vehicle class vehicle size
# 0          292.800000  Four-Door Car      Medsize
# 1          744.924331  Four-Door Car      Medsize
#
# [2 rows x 25 columns]

# %%
marketing_data['effective to date'].head(4)
# Out:
# 0   2011-02-18
# 1   2011-01-18
# 2   2011-02-10
# 3   2011-01-11
# Name: effective to date, dtype: datetime64[ns]

# %%
# 2. Create a new column 'effective to month' that stores only the months
import datetime

marketing_data['effective to month'] = pd.DatetimeIndex(marketing_data['effective to date']).month

display(marketing_data.head(2))
# Out:
#    unnamed: 0 customer       state  customer lifetime value response coverage  \
# 0           0  DK49336     Arizona              4809.216960       No    Basic
# 1           1  KX64629  California              2228.525238       No    Basic
#
#   education effective to date employmentstatus gender  ...  \
# 0   College        2011-02-18         Employed      M  ...
# 1   College        2011-01-18       Unemployed      F  ...
#
#    number of open complaints number of policies     policy type        policy  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
#
#    renew offer type  sales channel  total claim amount  vehicle class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
#
#   vehicle size effective to month
# 0      Medsize                  2
# 1      Medsize                  1
#
# [2 rows x 26 columns]

# %%
# 3. Filter the data only for the first quarter, but first we need to convert the column into datatime

months = pd.date_range(start='01-JAN-2011', end='24-JAN-2011')

marketing_data['effective to month'][marketing_data['effective to month'].index.month >=(marketing['effective to month'].index.date[-1].month-3)
# Out:
#   File "/var/folders/15/hgt62pt91txfslsjk64n8zd40000gp/T/ipykernel_2655/2635388573.py", line 5
#     marketing_data['effective to month'][marketing_data['effective to month'].index.month >=(marketing['effective to month'].index.date[-1].month-3)
#                                                                                                                                                     ^
# SyntaxError: unexpected EOF while parsing

# %%
# Exercise 7 - Put everything into a data transformation function, put everything i cleaned into a new function

# %%
# Exporting this processed data to a csv

marketing_data.to_csv('marketing_customer_analysis_round2.csv')

# %% [markdown]
# ROUND 3
#
# plot1 = yes and no diagram
#
# Create a new column called response rate put answer yes = 1 and no = 0
# - calculate the response rate, by creating a new column that gets a 1 when it is yes and a 0 when it is no
#
# plot 2 = x = sales
# plot 3 = x = total claim amount (might need to do something to those)
# plot 4 = x = income (might need to do something to those)

# %%
# Exercise 1 - show the dataframe info
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

display(marketing_data.head())
marketing_data.shape
# Out:
#    unnamed: 0 customer       state  customer lifetime value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective to date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number of open complaints number of policies     policy type        policy  \
# 0                   0.000000                  9  Corporate Auto  Corporate L3
# 1                   0.000000                  1   Personal Auto   Personal L3
# 2                   0.000000                  2   Personal Auto   Personal L3
# 3                   0.000000                  2  Corporate Auto  Corporate L3
# 4                   0.383567                  7   Personal Auto   Personal L2
#
#    renew offer type  sales channel  total claim amount  vehicle class  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
# 2            Offer3    Call Center          480.000000            SUV
# 3            Offer2         Branch          484.013411  Four-Door Car
# 4            Offer1         Branch          707.925645  Four-Door Car
#
#   vehicle size effective to month
# 0      Medsize                  2
# 1      Medsize                  1
# 2      Medsize                  2
# 3      Medsize                  1
# 4      Medsize                  1
#
# [5 rows x 26 columns]
# (10279, 26)

# %%
# Exercise 2 - describe dataframe

# get a picture of the numerical variables
display(marketing_data.describe().T) #turn the table around to get a clear picture of the dataframe
display(marketing_data.describe(include=[np.object]).T)
# Out:
#                                  count          mean           std  \
# unnamed: 0                     10279.0   5473.485650   3149.220531
# customer lifetime value        10279.0   8029.229015   6917.287221
# income                         10279.0  37541.332425  30350.225408
# monthly premium auto           10279.0     93.245063     34.445333
# months since last claim        10279.0     15.129851      9.768734
# months since policy inception  10279.0     48.134157     27.921951
# number of open complaints      10279.0      0.383567      0.883937
# number of policies             10279.0      2.970912      2.394379
# total claim amount             10279.0    435.736506    292.321294
# effective to month             10279.0      1.464442      0.498758
#
#                                        min          25%           50%  \
# unnamed: 0                        0.000000  2742.500000   5485.000000
# customer lifetime value        1898.007675  4013.084627   5780.182197
# income                            0.000000     0.000000  33837.000000
# monthly premium auto             61.000000    68.000000     83.000000
# months since last claim           0.000000     7.000000     15.000000
# months since policy inception     0.000000    24.000000     48.000000
# number of open complaints         0.000000     0.000000      0.000000
# number of policies                1.000000     1.000000      2.000000
# total claim amount                0.099007   272.788141    384.000000
# effective to month                1.000000     1.000000      1.000000
#
#                                         75%           max
# unnamed: 0                      8205.500000  10908.000000
# customer lifetime value         8992.381828  83325.381190
# income                         62100.500000  99981.000000
# monthly premium auto             109.000000    298.000000
# months since last claim           23.000000     35.000000
# months since policy inception     71.000000     99.000000
# number of open complaints          0.383567      5.000000
# number of policies                 4.000000      9.000000
# total claim amount               548.327777   2893.239678
# effective to month                 2.000000      2.000000
# /var/folders/15/hgt62pt91txfslsjk64n8zd40000gp/T/ipykernel_2655/4029119431.py:5: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   display(marketing_data.describe(include=[np.object]).T)
#                   count unique            top  freq
# customer          10279   9134        ID89933     5
# state             10279      5     California  3552
# response          10279      2             No  8813
# coverage          10279      3          Basic  6284
# education         10279      5       Bachelor  3094
# employmentstatus  10279      5       Employed  6398
# gender            10279      2              F  5232
# location code     10279      3       Suburban  6519
# marital status    10279      3        Married  5949
# policy type       10279      3  Personal Auto  7664
# policy            10279      9    Personal L3  3867
# renew offer type  10279      4         Offer1  4225
# sales channel     10279      4          Agent  3890
# vehicle class     10279      6  Four-Door Car  5500
# vehicle size      10279      3        Medsize  7406

# %%
# get a picture of all the variables 
display(marketing_data.describe(include='all').T)
# Out:
# /var/folders/15/hgt62pt91txfslsjk64n8zd40000gp/T/ipykernel_2655/3023195842.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   display(marketing_data.describe(include='all').T)
#                                  count unique                  top  freq  \
# unnamed: 0                     10279.0    NaN                  NaN   NaN
# customer                         10279   9134              ID89933     5
# state                            10279      5           California  3552
# customer lifetime value        10279.0    NaN                  NaN   NaN
# response                         10279      2                   No  8813
# coverage                         10279      3                Basic  6284
# education                        10279      5             Bachelor  3094
# effective to date                10279     59  2011-01-27 00:00:00   225
# employmentstatus                 10279      5             Employed  6398
# gender                           10279      2                    F  5232
# income                         10279.0    NaN                  NaN   NaN
# location code                    10279      3             Suburban  6519
# marital status                   10279      3              Married  5949
# monthly premium auto           10279.0    NaN                  NaN   NaN
# months since last claim        10279.0    NaN                  NaN   NaN
# months since policy inception  10279.0    NaN                  NaN   NaN
# number of open complaints      10279.0    NaN                  NaN   NaN
# number of policies             10279.0    NaN                  NaN   NaN
# policy type                      10279      3        Personal Auto  7664
# policy                           10279      9          Personal L3  3867
# renew offer type                 10279      4               Offer1  4225
# sales channel                    10279      4                Agent  3890
# total claim amount             10279.0    NaN                  NaN   NaN
# vehicle class                    10279      6        Four-Door Car  5500
# vehicle size                     10279      3              Medsize  7406
# effective to month             10279.0    NaN                  NaN   NaN
#
#                                    first       last          mean  \
# unnamed: 0                           NaT        NaT    5473.48565
# customer                             NaT        NaT           NaN
# state                                NaT        NaT           NaN
# customer lifetime value              NaT        NaT   8029.229015
# response                             NaT        NaT           NaN
# coverage                             NaT        NaT           NaN
# education                            NaT        NaT           NaN
# effective to date             2011-01-01 2011-02-28           NaN
# employmentstatus                     NaT        NaT           NaN
# gender                               NaT        NaT           NaN
# income                               NaT        NaT  37541.332425
# location code                        NaT        NaT           NaN
# marital status                       NaT        NaT           NaN
# monthly premium auto                 NaT        NaT     93.245063
# months since last claim              NaT        NaT     15.129851
# months since policy inception        NaT        NaT     48.134157
# number of open complaints            NaT        NaT      0.383567
# number of policies                   NaT        NaT      2.970912
# policy type                          NaT        NaT           NaN
# policy                               NaT        NaT           NaN
# renew offer type                     NaT        NaT           NaN
# sales channel                        NaT        NaT           NaN
# total claim amount                   NaT        NaT    435.736506
# vehicle class                        NaT        NaT           NaN
# vehicle size                         NaT        NaT           NaN
# effective to month                   NaT        NaT      1.464442
#
#                                         std          min          25%  \
# unnamed: 0                      3149.220531          0.0       2742.5
# customer                                NaN          NaN          NaN
# state                                   NaN          NaN          NaN
# customer lifetime value         6917.287221  1898.007675  4013.084627
# response                                NaN          NaN          NaN
# coverage                                NaN          NaN          NaN
# education                               NaN          NaN          NaN
# effective to date                       NaN          NaN          NaN
# employmentstatus                        NaN          NaN          NaN
# gender                                  NaN          NaN          NaN
# income                         30350.225408          0.0          0.0
# location code                           NaN          NaN          NaN
# marital status                          NaN          NaN          NaN
# monthly premium auto              34.445333         61.0         68.0
# months since last claim            9.768734          0.0          7.0
# months since policy inception     27.921951          0.0         24.0
# number of open complaints          0.883937          0.0          0.0
# number of policies                 2.394379          1.0          1.0
# policy type                             NaN          NaN          NaN
# policy                                  NaN          NaN          NaN
# renew offer type                        NaN          NaN          NaN
# sales channel                           NaN          NaN          NaN
# total claim amount               292.321294     0.099007   272.788141
# vehicle class                           NaN          NaN          NaN
# vehicle size                            NaN          NaN          NaN
# effective to month                 0.498758          1.0          1.0
#
#                                        50%          75%          max
# unnamed: 0                          5485.0       8205.5      10908.0
# customer                               NaN          NaN          NaN
# state                                  NaN          NaN          NaN
# customer lifetime value        5780.182197  8992.381828  83325.38119
# response                               NaN          NaN          NaN
# coverage                               NaN          NaN          NaN
# education                              NaN          NaN          NaN
# effective to date                      NaN          NaN          NaN
# employmentstatus                       NaN          NaN          NaN
# gender                                 NaN          NaN          NaN
# income                             33837.0      62100.5      99981.0
# location code                          NaN          NaN          NaN
# marital status                         NaN          NaN          NaN
# monthly premium auto                  83.0        109.0        298.0
# months since last claim               15.0         23.0         35.0
# months since policy inception         48.0         71.0         99.0
# number of open complaints              0.0     0.383567          5.0
# number of policies                     2.0          4.0          9.0
# policy type                            NaN          NaN          NaN
# policy                                 NaN          NaN          NaN
# renew offer type                       NaN          NaN          NaN
# sales channel                          NaN          NaN          NaN
# total claim amount                   384.0   548.327777  2893.239678
# vehicle class                          NaN          NaN          NaN
# vehicle size                           NaN          NaN          NaN
# effective to month                     1.0          2.0          2.0

# %%
# Exercise 3 - show a plot of the total number of responses
sns.displot(marketing_data['response'], bins=2) #the distribution is 2 because it is either yes or no
plt.show()

# %%
# Exercise 4 - show a plot of the response rate by the sales channel

#Create a new column called response rate put answer yes = 1 and no = 0

def clean_response(x):
    if x == 'Yes':
        return 1
    else:
        return 0
    
# Now create a new column 'response rate'
marketing_data['response rate'] = list(map(clean_response, marketing_data['response']))
display(marketing_data['response rate'].unique())

# check dataframe
marketing_data['response rate'].value_counts()
# Out:
# array([0, 1])
# 0    8813
# 1    1466
# Name: response rate, dtype: int64

# %%
# x = sales channel and y = response rate
marketing_data['sales channel'].unique()
# Out:
# array(['Agent', 'Call Center', 'Branch', 'Web'], dtype=object)

# %%
sns.barplot(x= "sales channel", y="response rate", data =marketing_data)
# Out:
# <AxesSubplot:xlabel='sales channel', ylabel='response rate'>

# %%
sns.countplot(data=marketing_data, x ="sales channel", hue="response rate")

# 0 = no and 1 = yes
# Out:
# <AxesSubplot:xlabel='sales channel', ylabel='count'>

# %%
sns.displot(data=marketing_data, x ="sales channel", hue="response rate", multiple="stack")

# %%
# Exercise 5 - show a plot of the response rate by the total claim amount

display(marketing_data['total claim amount'].describe().T)
# Out:
# count    10279.000000
# mean       435.736506
# std        292.321294
# min          0.099007
# 25%        272.788141
# 50%        384.000000
# 75%        548.327777
# max       2893.239678
# Name: total claim amount, dtype: float64

# %%
# It would make sense to look at the data in a boxplot and see the outliers depending on the quartiles

#We need to do something with the total claim amount
# I would group the total claims in the different quartiles
#sns.boxplot(data=marketing_data, x="total claim amount", y = "response rate", hue ="response rate")
# bin my claimns
sns.displot(data=marketing_data['total claim amount'], bins = 4)
sns.displot(data=marketing_data, x ="total claim amount", hue="response rate", multiple="stack", bins=8)
